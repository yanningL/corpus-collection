# %%
# Import libraries
from nntplib import NNTP
import numpy as np
import os
import csv
######################################

def find_unique_subjects_and_authors(items_original):
    
    # Empty list
    items_reformatted = []

    # Create new list of tuples with only relevent details
    for message_number, subject, author, date, message_id, references, size, lines in items_original:
        # Remove "Re: " in subject line
        if subject[0:4] == "Re: ":
            subject = subject[4:]
        items_reformatted.append((message_number, subject, author))

    # Convert to numpy array
    dtype = [('message_number', int), ('subject', 'S40'), ('author', 'S40')]
    items_array = np.array(items_reformatted, dtype = dtype)

    # Sort by subject
    items_array_sort = np.sort(items_array, axis=0, order="subject")
        
    # Iterate through subjects to find unique subjects and authors
    subject_number = 0
    subject_current = ''
    authors = []
    author_numbers = []
    items_array_new = []
    for item in items_array_sort:
        if item[1] != subject_current:
            subject_current = item[1]
            subject_number += 1
            authors = []
            author_numbers.append(0)
        if item[2] not in authors:
            authors.append(item[2])
            author_numbers[-1] += 1
        items_array_new.append((int(item[0]), subject_number, authors.index(item[2])+1))
        
    # Return array of unique subjects and authors
    return items_array_new, subject_number, author_numbers

######################################

def combine_conversations(items_to_combine, number_of_subjects):
    
    # Create blank array
    conversations = []
    for i in range(number_of_subjects):
        conversations.append('<s>')
    
    # Parse the message
    for message_number, subject_number, author_number in items_to_combine:
        
        # Read header and body
        resp, number, id, text = s.article(str(message_number))
        
        # Determine encoding
        encoding = 'none'
        for line in text:
            if line[0:18] == 'Content-Type: text':
                index = line.find('charset')
                if index != -1:
                    encoding = line[index+8:]
                    end = min(encoding.find(';'), encoding.find(' '))
                    if end != -1:
                        encoding = encoding[0:end]
                    # print "DEBUG: line + " === " + encoding
        encoding2 = 'none'
        for line in text:
            if line[0:27] == 'Content-Transfer-Encoding: ':
                encoding2 = line[27:]
        
        # print "DEBUG: line + " === " + encoding
        print "-- Message [" + str(message_number) + "] Subject [" + str(subject_number) + "] Author [" + str(author_number) + "]" + " Encoding [" + encoding + "," + encoding2 + "]"
        
        # Setup variables to parse body
        header = True
        finish = False
        output = ""

        # Parse body of post
        # ***************** THIS PART NEEDS EXCEPTION CATCHING AS IF ENCODING DOES NOT MATCH MESSAGE IT CRASHES *************
        try:
            for line_raw in text:
                # Decode text into UTF-8
                if encoding == 'none':
                    line = line_raw.encode('utf-8')
                else:
                    line = line_raw.decode(encoding).encode('utf-8')
                # Parse pre-signature limiter
                if line[0:2] == "--":
                    finish = True    
                # Add line if appropriate
                if header == False and finish == False and line[0:1] != '>' and 'wrote:' not in line and 'a écrit :' not in line and len(line) > 0:
                    # print line
                    if len(output) == 0:
                        output = line
                    else:
                        if output[-1:] == ' ':
                            output = output + line
                        else:
                            output = output + " " + line                        
                # Find end of header
                if line == '':
                    header = False
        except UnicodeDecodeError:
            print " -- -- -- Unicode Decode Error caught -- -- --"
        except LookupError:
            print " -- -- -- Lookup Error caught -- -- --"
        print "DEBUG: " + output[0:50]

        #print subject_number, author_number, output[0:39]
        conversations[subject_number - 1] += '<utt uid="' + str(author_number) + '">' + output + '</utt>'
        #print conversations[subject_number - 1]
        #print "DEBUG: " + output[0:40]

    # Insert end-limiter for conversations
    for i in range(number_of_subjects):
        conversations[i] += '</s>'

    return conversations

######################################

# Open news server
#s = NNTP('freenews.netfront.net', readermode=True)
s = NNTP('blaine.gmane.org', readermode=True)
#s = NNTP('news2.informatik.uni-stuttgart.de', readermode=True) - does not return groups
print "Opened connection to news server"

# Read pre-existing group list if available
if os.path.isfile('groups.txt'):
    french_groups = []
    with open('groups.txt') as f:
        for line in f:
            french_groups.append(line[:-1])
    print "- read " + str(len(french_groups)) + " French groups from file"
# Otherwise create from server
else: 
    # Read group list
    groups = s.list()
    print "- there are " + str(len(groups[1])) + " groups in total"

    # Create empty list for French groups
    french_groups = []

    # Find French groups
    for group in groups[1]:
        currgroup = group[0]
        #if currgroup[0:2] == 'fr':
        if 'french' in currgroup:
            french_groups.append(group[0])
    print "- there are " + str(len(french_groups)) + " groups in French"

    # Save French groups
    with open('groups.txt', 'w') as f:
        for group in french_groups:
            f.write(group + "\n")
    print "- written to file"

# Open file to write
f = open('samplegroup_fra.xml', 'w')
g = open('stats_message.csv', 'wb')

group_writer = csv.writer(g)
group_writer.writerow(['Group', 'No. of messages', 'No. of authors']) 
# Iterate through French groups (only subset at present)

for group in french_groups[0:5]:
    # ********** THIS NEEDS TO BE CHANGED TO LOOK AT ALL GROUPS FOR FINAL VERSION ************
    
    # Read number of messages in group
    resp, count, first, last, name = s.group(group)
    print "Group [" + group + "] has " + count + " articles (" + first + ", " + last + ")"
    
    # Read items info from group
    print "- Reading items"
    
    # DEBUG - ******** THIS NEEDS TO BE REMOVED, IT JUST LOOKS AT LAST 50 MESSAGES TO SAVE TIME FOR NOW *********
    if int(last)-int(first) > 200:
        first = str(int(last)-200)
        print "-- DEBUG: Truncating to (" + first + "," + last + ")"
    # DEBUG
    
    resp, items = s.xover(first, last)
        
    # Find unique subjects and authors
    print "- Sorting items"
    items_unique, subject_number, author_numbers = find_unique_subjects_and_authors(items)
    print "-- There are " + str(subject_number) + " unique subjects in this forum"
    
    # ******* NEED TO WRITE THE GROUP, NUMBER OF MESSAGES etc. TO A FILE g FOR STATISTICS *******
    group_writer.writerow([group, subject_number, sum(author_numbers)])
    
    # Combine conversations
    print "- Combining conversations"
    conversations = combine_conversations(items_unique, subject_number)
    
    # creat h stats for each group
    hname="stats_author_"+group+".csv"
    h=open(hname,'wb')
    author_writer = csv.writer(h)
    author_writer.writerow(['Conversation no.', 'No. of authors']) 
        
    index = 0
    counter = 1
    for dialog in conversations:
        if author_numbers[index] >= 2:
            f.write('<dialog>\n')
            f.write(dialog + '\n')
            f.write('</dialog>\n')
            print "-- Writing conversation on subject " + str(index + 1)
            print "DEBUG: " + dialog
            author_writer.writerow([counter,author_numbers[index]])
            counter += 1
        index += 1
        
    # ****** Written for now conversation number and number of authors in that conversation (added in above code) *******
    
# Close file
f.close()
g.close()
h.close()
# Out:
# Opened connection to news server
# - read 79 French groups from file
# Group [gmane.linux.debian.user.french] has 204097 articles (1, 205169)
# - Reading items
# -- DEBUG: Truncating to (204969,205169)
# - Sorting items
# -- There are 75 unique subjects in this forum
# - Combining conversations
# -- Message [205141] Subject [1] Author [1] Encoding [none,8BIT]
#  -- -- -- Unicode Decode Error caught -- -- --
# DEBUG:   This message is in MIME format.  The first part
# -- Message [205142] Subject [2] Author [1] Encoding ["UTF-8",8bit]
# DEBUG: Je ne reproche rien à JFS, sinon d'être populair
# -- Message [205165] Subject [3] Author [1] Encoding ["UTF-8",8bit]
# DEBUG: Bonjour Ca fait plaisir de voir des messages de su
# -- Message [205057] Subject [4] Author [1] Encoding ["UTF-8",8bit]
# DEBUG: Bonjour Si Network Manager est isntallé, in peut
# -- Message [205139] Subject [5] Author [1] Encoding ["UTF-8",8bit]
# DEBUG: Bonjour Quelques questions: Les SSD prennent ils e
# -- Message [205160] Subject [5] Author [1] Encoding ["UTF-8",8bit]
# DEBUG: Bonjour Pour info je suis avec Debian Sid et j'ai
# -- Message [205070] Subject [6] Author [1] Encoding ["UTF-8",quoted-printable]
# DEBUG:
# -- Message [204988] Subject [7] Author [1] Encoding [UTF-8,quoted-printable]
# DEBUG:
# -- Message [204997] Subject [7] Author [2] Encoding ["iso-8859-1",quoted-printable]
# DEBUG: Bonsoir, Pour vous embetez, la commande rm n'est p
# -- Message [205136] Subject [8] Author [1] Encoding ["UTF-8",quoted-printable]
# DEBUG:
# -- Message [205140] Subject [9] Author [1] Encoding ["UTF-8",quoted-printable]
# DEBUG:
# -- Message [205073] Subject [10] Author [1] Encoding ["UTF-8",quoted-printable]
# DEBUG: online.net ? Le 15 septembre 2017 =C3=A0 10:12, Da
# -- Message [205075] Subject [10] Author [2] Encoding ["UTF-8",quoted-printable]
# DEBUG:
# -- Message [205079] Subject [10] Author [2] Encoding ["UTF-8",quoted-printable]
# DEBUG:
# -- Message [205083] Subject [10] Author [2] Encoding ["UTF-8",quoted-printable]
# DEBUG:
# -- Message [205085] Subject [10] Author [2] Encoding ["UTF-8",quoted-printable]
# DEBUG:
# -- Message [205121] Subject [11] Author [1] Encoding [utf-8,8bit]
# DEBUG: Bonjour, J'ai un fichier CSV avec des identifiants
# -- Message [204982] Subject [12] Author [1] Encoding [utf-8,8bit]
# DEBUG: Bonjour, Je viens de ré-installer mon système su
# -- Message [204973] Subject [13] Author [1] Encoding [utf-8,8bit]
# DEBUG: Le 07/09/2017 à 23:49, roger.tarani@free.fr a éc
# -- Message [204974] Subject [13] Author [1] Encoding [utf-8,8bit]
# DEBUG: Le 07/09/2017 à 22:00, roger.tarani@free.fr a éc
# -- Message [205124] Subject [14] Author [1] Encoding [iso-8859-15,8bit]
# DEBUG: Le 09/20/17 à 17:25, Yves Rutschle a écrit : ET
# -- Message [205125] Subject [14] Author [2] Encoding [iso-8859-15,8bit]
# DEBUG: Malheureusement, ce n'est pas moi qui produit le f
# -- Message [205025] Subject [15] Author [1] Encoding [utf-8,8bit]
# DEBUG: Bonjour, Le lien pasbin est mort. Que dit :   dpkg
# -- Message [205166] Subject [16] Author [1] Encoding [utf-8,8bit]
# DEBUG: Le 24/09/2017 à 21:04, MERLIN Philippe a écrit
# -- Message [205167] Subject [16] Author [2] Encoding [utf-8,8bit]
# DEBUG: Bonjour, tu chipotes un peu ;-) Attention avec l'o
# -- Message [205168] Subject [16] Author [3] Encoding [utf-8,8bit]
# DEBUG: Le 25/09/2017 à 14:13, Stephane Ascoet a écrit
# -- Message [204984] Subject [17] Author [1] Encoding [utf-8,8bit]
# DEBUG: Hello, Je ne suis pas sûr d'avoir compris comment
# -- Message [204985] Subject [17] Author [1] Encoding [utf-8,8bit]
# DEBUG: Je ne pense pas. On peut écrire : if [ -e "$fichi
# -- Message [204991] Subject [17] Author [1] Encoding [utf-8,8bit]
# DEBUG: root@stretch-clean:~# ls /etc/apt/sources.list.d/
# -- Message [204995] Subject [17] Author [2] Encoding [utf-8,8bit]
# DEBUG: Re-bonjour, C'est tout à fait ça ;-) Il ne march
# -- Message [205000] Subject [17] Author [1] Encoding [utf-8,8bit]
# DEBUG: ... sauf si le répertoire /etc/apt/source.list.d/
# -- Message [205001] Subject [17] Author [3] Encoding [utf-8,8bit]
# DEBUG: Bonsoir François, Vous pinaillez, oui et non, Si
# -- Message [205138] Subject [18] Author [1] Encoding [utf-8,8bit]
# DEBUG: This is a multi-part message in MIME format.
# -- Message [205144] Subject [18] Author [2] Encoding [utf-8,8bit]
# DEBUG: Tu peux essayer de jouer avec le cible LOG ( ou au
# -- Message [205081] Subject [19] Author [1] Encoding [utf-8,8bit]
# DEBUG: Le 15/09/2017 à 10:12, David Martin a écrit : J
# -- Message [205084] Subject [19] Author [2] Encoding [utf-8,quoted-printable]
# DEBUG: This is an OpenPGP/MIME signed message (RFC 4880 a
# -- Message [205088] Subject [20] Author [1] Encoding [utf-8,8bit]
# DEBUG: En fait, si j'ai bien compris ta demande, ça revi
# -- Message [205117] Subject [20] Author [2] Encoding [utf-8,8bit]
# DEBUG: Bonjour, il y a aussi le Org-mode de Emacs qui est
# -- Message [205008] Subject [21] Author [1] Encoding ["UTF-8",quoted-printable]
# DEBUG:
# -- Message [205169] Subject [22] Author [1] Encoding ["UTF-8",quoted-printable]
# DEBUG: Le 25 septembre 2017 =C3=A0 12:48, Pascal Hambourg
# -- Message [205095] Subject [23] Author [1] Encoding ["UTF-8",quoted-printable]
# DEBUG:
# -- Message [205097] Subject [23] Author [1] Encoding ["UTF-8",quoted-printable]
# DEBUG:
# -- Message [205120] Subject [23] Author [1] Encoding ["UTF-8",quoted-printable]
# DEBUG:
# -- Message [205127] Subject [23] Author [1] Encoding ["UTF-8",quoted-printable]
# DEBUG:
# -- Message [205128] Subject [23] Author [1] Encoding ["UTF-8",none]
# DEBUG:
# -- Message [205086] Subject [24] Author [1] Encoding ["UTF-8",quoted-printable]
# DEBUG:
# -- Message [205026] Subject [25] Author [1] Encoding [utf-8,quoted-printable]
# DEBUG: This is an OpenPGP/MIME signed message (RFC 4880 a
# -- Message [205030] Subject [26] Author [1] Encoding ["UTF-8",quoted-printable]
# DEBUG:
# -- Message [204986] Subject [27] Author [1] Encoding [iso-8859-1,8bit]
# DEBUG: Hello, [...] [...] Ça s'exécute forcément en ro
# -- Message [204987] Subject [27] Author [2] Encoding [iso-8859-1,8bit]
# DEBUG: salut, si tu mets ton * dans une chaine (""), c'es
# -- Message [204992] Subject [27] Author [2] Encoding [us-ascii,none]
# DEBUG: oops ... effectivement :) utilise find !
# -- Message [205089] Subject [28] Author [1] Encoding [iso-8859-1,8bit]
# DEBUG: Lo, [...] Tu y arriverais avec ikiwiki. Ça prend
# -- Message [205090] Subject [28] Author [2] Encoding [iso-8859-1,8bit]
# DEBUG: degainer php pour ca me semble bien overkill ... p
# -- Message [205092] Subject [28] Author [2] Encoding [iso-8859-1,8bit]
# DEBUG: c'était pas toi mais david qui parlait de php et
# -- Message [205094] Subject [28] Author [2] Encoding [iso-8859-1,8bit]
# DEBUG: pardon ... j'aurais du me garder de cette phrase p
# -- Message [205096] Subject [28] Author [2] Encoding [iso-8859-1,8bit]
# DEBUG: non: on a juste plus d'heures de pratique que toi.
# -- Message [205047] Subject [29] Author [1] Encoding [utf-8,base64]
# DEBUG: PGRpdj5Cb25qb3VyLCBqZSBtZSBzdWlzIHJlbmR1IGNvbXB0ZS
# -- Message [205040] Subject [30] Author [1] Encoding [utf-8,base64]
# DEBUG: PGRpdj5Cb25qb3VyLCBkw6lzb2zDqSBwb3VyIGxlIHJldGFyZC
# -- Message [205087] Subject [31] Author [1] Encoding [utf-8,8bit]
# DEBUG: Salut David, Je ne connais pas de projet libre qui
# -- Message [205091] Subject [31] Author [1] Encoding [utf-8,8bit]
# DEBUG: Oups, ma langue a fourché, je voulais dire python
# -- Message [205093] Subject [31] Author [1] Encoding [utf-8,8bit]
# DEBUG: D'accord avec le premier, mais pourquoi diable le
# -- Message [205098] Subject [31] Author [1] Encoding [utf-8,8bit]
# DEBUG: Et en plus on est 'dredi  ;)
# -- Message [205099] Subject [31] Author [1] Encoding [utf-8,8bit]
# DEBUG: Solution très élégante par ailleurs…
# -- Message [205126] Subject [31] Author [2] Encoding [utf-8,8bit]
# DEBUG:   Salut David,   Pour mettre en oeuvre la suggesti
# -- Message [204983] Subject [32] Author [1] Encoding [utf-8,quoted-printable]
# DEBUG: David BERCOT <debian@bercot.org> writes: il manque
# -- Message [205006] Subject [32] Author [1] Encoding [utf-8,quoted-printable]
# DEBUG: =C3=89tienne Mollier <etienne.mollier@mailoo.org>
# -- Message [204969] Subject [33] Author [1] Encoding [utf-8,quoted-printable]
# DEBUG: Oups ! C'est le kernel qui est en v4 : "Powered by
# -- Message [204970] Subject [33] Author [1] Encoding [utf-8,quoted-printable]
# DEBUG: Merci Pascal, Avant de faire ce test : Le d=C3=A9c
# -- Message [204972] Subject [33] Author [1] Encoding [utf-8,quoted-printable]
# DEBUG: Un gars =C3=A9voque le fait qu'un liveCD a endomma
# -- Message [204976] Subject [33] Author [1] Encoding [utf-8,quoted-printable]
# DEBUG: Bonjour Revoici le lien (copi=C3=A9 dans la barre
# -- Message [204981] Subject [33] Author [1] Encoding [utf-8,quoted-printable]
# DEBUG: Bonjour Concr=C3=A8tement, comment faut-il proc=C3
# -- Message [205010] Subject [33] Author [1] Encoding [utf-8,quoted-printable]
# DEBUG: PS L'=C3=A9quipe Cryptsetup avait r=C3=A9pondu =C3
# -- Message [205011] Subject [33] Author [2] Encoding [utf-8,quoted-printable]
# DEBUG: Bonjour, Pour la g=C3=A9n=C3=A9ration d'un bug : -
# -- Message [205012] Subject [33] Author [1] Encoding [utf-8,quoted-printable]
# DEBUG: Bonjour, Dans mon cas, la machine a =C3=A9t=C3=A9
# -- Message [205013] Subject [33] Author [1] Encoding [utf-8,quoted-printable]
# DEBUG: Bonjour, Dans mon cas, la machine a =C3=A9t=C3=A9
# -- Message [205028] Subject [33] Author [1] Encoding [utf-8,quoted-printable]
# DEBUG: Bonjour Il reste le dernier test =C3=A0 faire avec
# -- Message [205048] Subject [33] Author [1] Encoding [utf-8,quoted-printable]
# DEBUG: Bonjour=20 J'ai cr=C3=A9=C3=A9 3 fichiers contenan
# -- Message [205027] Subject [34] Author [1] Encoding [utf-8,quoted-printable]
# DEBUG:
# -- Message [205108] Subject [35] Author [1] Encoding [none,quoted-printable]
# DEBUG:
# -- Message [205149] Subject [36] Author [1] Encoding [utf-8,quoted-printable]
# DEBUG: Salut Bernard. Audacity fais =C3=A7a tr=C3=A8s bie
# -- Message [205114] Subject [37] Author [1] Encoding [utf-8,quoted-printable]
# DEBUG: L'autocompl=C3=A9tion =C3=A0 encore frapp=C3=A9. J
# -- Message [205113] Subject [38] Author [1] Encoding [utf-8,quoted-printable]
# DEBUG: J'ai 2 installations d=C3=A9cembre et synatic se l
# -- Message [205119] Subject [39] Author [1] Encoding [utf-8,quoted-printable]
# DEBUG: bonjour, j'utilise sqlite et je souhaiterai r=C3=A
# -- Message [205148] Subject [40] Author [1] Encoding [utf-8,7bit]
# DEBUG: bonjour, cf sujet en employant que les logiciels l
# -- Message [204979] Subject [41] Author [1] Encoding [utf-8,8bit]
# DEBUG: Bonjour, J’avais pourtant jeté un œil dans mon
# -- Message [204990] Subject [41] Author [1] Encoding [utf-8,8bit]
# DEBUG: Concrètement, je t’ai donné une liste de comma
# -- Message [205051] Subject [41] Author [1] Encoding [utf-8,8bit]
# DEBUG: Bonsoir, Mon système est également chiffré avec
# -- Message [205056] Subject [41] Author [1] Encoding [utf-8,8bit]
# DEBUG: Bonjour, À part compiler depuis les sources upstr
# -- Message [205135] Subject [42] Author [1] Encoding [UTF-8;,8bit]
# DEBUG: Bonjour. Désolé du silence, j'ai quelques probl�
# -- Message [205032] Subject [43] Author [1] Encoding [UTF-8,8bit]
# DEBUG: 	Bonjour à tous, 	J'utilise sendmail depuis très
# -- Message [205033] Subject [43] Author [1] Encoding [UTF-8,8bit]
# DEBUG: Rhohhh pétard, c'est encore bien pire que cela :
# -- Message [205034] Subject [43] Author [2] Encoding [utf-8,8bit]
# DEBUG: J'ai eu un problème similaire avec postfix pour l
# -- Message [205035] Subject [43] Author [3] Encoding [utf-8,8bit]
# DEBUG: Le 13/09/2017 à 15:00, BERTRAND Joël a écrit :
# -- Message [205036] Subject [43] Author [1] Encoding [UTF-8,8bit]
# DEBUG: 	Très certes. J'avais bien vu ça. Sauf que j'ava
# -- Message [205037] Subject [43] Author [1] Encoding [UTF-8,8bit]
# DEBUG: 	Je viens de répondre sur ce bug. Et j'ai recompi
# -- Message [205038] Subject [43] Author [4] Encoding [utf-8,8bit]
# DEBUG: C'est peut-être une question un peu naïve, mais
# -- Message [205039] Subject [43] Author [1] Encoding [UTF-8,8bit]
# DEBUG: 	Ce n'est pas unstable mais testing parce que stab
# -- Message [205041] Subject [43] Author [4] Encoding [utf-8,8bit]
# DEBUG: Le 13/09/2017 à 17:35, BERTRAND Joël a écrit :
# -- Message [205049] Subject [43] Author [5] Encoding [iso-8859-1,8bit]
# DEBUG: Mais avec les notes de publication qui y répondro
# -- Message [205122] Subject [44] Author [1] Encoding [iso-8859-15,8bit]
# DEBUG: C'est mal, il faut hacher les mots de passe. En Pe
# -- Message [205123] Subject [45] Author [1] Encoding [iso-8859-1,8bit]
# DEBUG: Donc ce que tu veux, ce sont toutes les lignes qui
# -- Message [205021] Subject [46] Author [1] Encoding ["UTF-8",8bit]
# DEBUG: Tout d'abord si tu évitait d'envoyer les messages
# -- Message [205050] Subject [46] Author [2] Encoding ["UTF-8",8bit]
# DEBUG: Tout d'abord si tu évitait d'envoyer les messages
# -- Message [205029] Subject [47] Author [1] Encoding [utf-8,quoted-printable]
# DEBUG:
# -- Message [205045] Subject [47] Author [1] Encoding [utf-8,8bit]
# DEBUG: Salut, Alors deux choses. Premièrement ton messag
# -- Message [205161] Subject [48] Author [1] Encoding ["iso-8859-1",quoted-printable]
# DEBUG: Bonjour, Je voudrais vous faire part de ma r=E9cen
# -- Message [205055] Subject [49] Author [1] Encoding [utf-8,8bit]
# DEBUG: Bonjour, Cron avec une entrée « @reboot » ?
# -- Message [205046] Subject [50] Author [1] Encoding [none,quoted-printable]
# DEBUG: Bonjour, ma connexion WiFi ne se lance pas automat
# -- Message [205066] Subject [51] Author [1] Encoding [utf-8,quoted-printable]
# DEBUG: Bonsoir, andre_debian@numericable.fr writes: =C3=A
# -- Message [205077] Subject [51] Author [2] Encoding [none,quoted-printable]
# DEBUG:  =C3=A9crit : =C3=A9 =80=A6 Je commencerais=20 =E2
# -- Message [205078] Subject [51] Author [1] Encoding [utf-8,quoted-printable]
# DEBUG: Pendant longtemps j=E2=80=99ai conserv=C3=A9 ma ge
# -- Message [205105] Subject [52] Author [1] Encoding ["iso-8859-1",quoted-printable]
# DEBUG: This is a multi-part message in MIME format.
# -- Message [205137] Subject [53] Author [1] Encoding [none,8BIT]
#  -- -- -- Unicode Decode Error caught -- -- --
# DEBUG:   This message is in MIME format.  The first part
# -- Message [205143] Subject [53] Author [1] Encoding [none,8BIT]
#  -- -- -- Unicode Decode Error caught -- -- --
# DEBUG:   This message is in MIME format.  The first part
# -- Message [205145] Subject [53] Author [2] Encoding [windows-1252,quoted-printable]
# DEBUG: This is an OpenPGP/MIME signed message (RFC 4880 a
# -- Message [205146] Subject [53] Author [3] Encoding [windows-1252,8bit]
# DEBUG: Le 23/09/2017 à 08:50, Pierre L. a écrit : A qu
# -- Message [205147] Subject [53] Author [1] Encoding [none,8BIT]
#  -- -- -- Unicode Decode Error caught -- -- --
# DEBUG:   This message is in MIME format.  The first part
# -- Message [205150] Subject [53] Author [3] Encoding [windows-1252,8bit]
# DEBUG: Le 23/09/2017 à 11:57, Seb a écrit : C'était c
# -- Message [205151] Subject [53] Author [4] Encoding [utf-8,8bit]
# DEBUG:     Bonjour, Le samedi 23 septembre 2017, Pascal H
# -- Message [205152] Subject [53] Author [2] Encoding [windows-1252,quoted-printable]
# DEBUG: This is an OpenPGP/MIME signed message (RFC 4880 a
# -- Message [205155] Subject [53] Author [3] Encoding [windows-1252,8bit]
# DEBUG: Le 23/09/2017 à 15:51, Pierre L. a écrit : Je l
# -- Message [205156] Subject [53] Author [5] Encoding [windows-1252,8bit]
# DEBUG: Le 22/09/2017 à 17:09, Seb a écrit : Tu as essa
# -- Message [205157] Subject [53] Author [1] Encoding [none,8BIT]
#  -- -- -- Unicode Decode Error caught -- -- --
# DEBUG:   This message is in MIME format.  The first part
# -- Message [205158] Subject [53] Author [6] Encoding [utf-8,quoted-printable]
# DEBUG:
# -- Message [204996] Subject [54] Author [1] Encoding [utf-8,quoted-printable]
# DEBUG:
# -- Message [204998] Subject [54] Author [2] Encoding ["UTF-8",quoted-printable]
# DEBUG:
# -- Message [204999] Subject [54] Author [3] Encoding [utf-8,8bit]
# DEBUG: Quelque uns de ceux là : dpkg-reconfigure keyboar
# -- Message [205159] Subject [55] Author [1] Encoding [utf-8,8bit]
# DEBUG: Bonjour, J'ai franchi le pas avec une Brother DCP-
# -- Message [205074] Subject [56] Author [1] Encoding [iso-8859-1,8bit]
# DEBUG: salut,   ARN ? http://arn-fai.net/ c'est associati
# -- Message [205076] Subject [56] Author [1] Encoding [iso-8859-1,8bit]
# DEBUG: j'ai une vm openbsd hebergée chez eux :) cordiale
# -- Message [205031] Subject [57] Author [1] Encoding [utf-8,quoted-printable]
# DEBUG: This is an OpenPGP/MIME signed message (RFC 4880 a
# -- Message [205042] Subject [57] Author [2] Encoding [utf-8,8bit]
# DEBUG: Salut, Cool, c'est quoi une KSP ? Dans quelle vill
# -- Message [205043] Subject [57] Author [3] Encoding [none,quoted-printable]
# DEBUG: Kerbal Space Program ??? https://fr.wikipedia.org/
# -- Message [205054] Subject [58] Author [1] Encoding [utf-8,8bit]
# DEBUG: Bonjour, Ce sujet a déjà été traité plusieurs
# -- Message [205058] Subject [58] Author [2] Encoding ["UTF-8",8bit]
# DEBUG: Le jeudi 14 septembre 2017 à 10:33 +0200, David B
# -- Message [205059] Subject [58] Author [1] Encoding [utf-8,8bit]
# DEBUG: Bonjour Jérôme, Pour répondre à ta première q
# -- Message [205060] Subject [58] Author [3] Encoding [utf-8,8bit]
# DEBUG: Bonsoir, Je suis plutôt interface graphique mais
# -- Message [205062] Subject [58] Author [1] Encoding [utf-8,8bit]
# DEBUG: Bonjour Yannick, Le 14/09/2017 à 17:19, Yannick a
# -- Message [205065] Subject [58] Author [4] Encoding [UTF-8,quoted-printable]
# DEBUG: Le Thu, 14 Sep 2017 17:42:16 +0200, David BERCOT <
# -- Message [205069] Subject [58] Author [5] Encoding [utf-8,8bit]
# DEBUG: Le 14/09/2017 à 10:33, David BERCOT a écrit : [
# -- Message [205071] Subject [58] Author [1] Encoding [utf-8,8bit]
# DEBUG: Bonjour, Le 14/09/2017 à 18:02, Haricophile a éc
# -- Message [205072] Subject [58] Author [1] Encoding [utf-8,8bit]
# DEBUG: Bonjour, Le 15/09/2017 à 09:23, didier gaumet a �
# -- Message [205082] Subject [58] Author [1] Encoding [utf-8,8bit]
# DEBUG: Le 15/09/2017 à 10:16, David BERCOT a écrit : R
# -- Message [205101] Subject [58] Author [5] Encoding [utf-8,8bit]
# DEBUG: Le 15/09/2017 à 14:31, David BERCOT a écrit : j
# -- Message [205110] Subject [59] Author [1] Encoding [utf-8,quoted-printable]
# DEBUG: This is an OpenPGP/MIME signed message (RFC 4880 a
# -- Message [205134] Subject [59] Author [2] Encoding [UTF-8,quoted-printable]
# DEBUG: Le Mon, 18 Sep 2017 14:07:46 +0200, "Pierre L." <p
# -- Message [205153] Subject [59] Author [1] Encoding [utf-8,quoted-printable]
# DEBUG: This is an OpenPGP/MIME signed message (RFC 4880 a
# -- Message [204994] Subject [60] Author [1] Encoding ["UTF-8",quoted-printable]
# DEBUG:
# -- Message [205002] Subject [60] Author [2] Encoding ["UTF-8",quoted-printable]
# DEBUG:
# -- Message [205005] Subject [60] Author [1] Encoding ["UTF-8",quoted-printable]
# DEBUG:
# -- Message [205009] Subject [61] Author [1] Encoding [utf-8,8bit]
# DEBUG: On Mon, Sep 11, 2017 at 12:24:43PM CEST, Michel Me
# -- Message [205007] Subject [62] Author [1] Encoding [none,quoted-printable]
# DEBUG: Bonjour, J'ai cr=E9=E9 une Mailing-Liste qui a tou
# -- Message [205044] Subject [62] Author [1] Encoding [none,quoted-printable]
# DEBUG: le Merci, mais il s'agit de la ML "mailman". Ou po
# -- Message [205132] Subject [63] Author [1] Encoding ["UTF-8",quoted-printable]
# DEBUG:
# -- Message [205133] Subject [63] Author [2] Encoding [utf-8,8bit]
# DEBUG: Bonsoir David, Une méthode assez simple et effica
# -- Message [205107] Subject [64] Author [1] Encoding ["iso-8859-1",quoted-printable]
# DEBUG: Mes excuses pour le bruit, une erreur de lecture d
# -- Message [205162] Subject [65] Author [1] Encoding [utf-8,8bit]
# DEBUG: Bonjour la liste, Mettons que je possède un site
# -- Message [205163] Subject [65] Author [2] Encoding [iso-8859-1,8bit]
# DEBUG:  Oui, et c'est un peu énervant avec les formulair
# -- Message [205164] Subject [65] Author [1] Encoding [utf-8,8bit]
# DEBUG: Le lundi 25 septembre 2017, Charles Plessy a écri
# -- Message [205053] Subject [66] Author [1] Encoding [UTF-8,quoted-printable]
# DEBUG:
# -- Message [204977] Subject [67] Author [1] Encoding [utf-8,7bit]
# DEBUG: bonjour, auriez vous l'amabilite de me desabonner.
# -- Message [204978] Subject [67] Author [2] Encoding [utf-8,quoted-printable]
# DEBUG: This is an OpenPGP/MIME signed message (RFC 4880 a
# -- Message [204980] Subject [67] Author [3] Encoding [utf-8,8bit]
# DEBUG: Pierre L. wrote on Fri, Sep 08, 2017 at 09:13:41AM
# -- Message [204989] Subject [67] Author [2] Encoding [utf-8,quoted-printable]
# DEBUG: This is an OpenPGP/MIME signed message (RFC 4880 a
# -- Message [205109] Subject [68] Author [1] Encoding [utf-8,quoted-printable]
# DEBUG: bonjour, j'ai opendkim qui fonctionne et pourtant
# -- Message [205061] Subject [69] Author [1] Encoding [utf-8,quoted-printable]
# DEBUG: bonjour, j'ai une erreur avec opendkim et je n'arr
# -- Message [205063] Subject [69] Author [2] Encoding [utf-8,8bit]
# DEBUG: Bonjour le répertoire /var/run/opendkim existe t'
# -- Message [205064] Subject [69] Author [1] Encoding [utf-8,quoted-printable]
# DEBUG:
# -- Message [205067] Subject [69] Author [3] Encoding [UTF-8,8bit]
# DEBUG: Bonsoir, vu que le message d'erreur ne correspond
# -- Message [205068] Subject [69] Author [1] Encoding [utf-8,quoted-printable]
# DEBUG:
# -- Message [205080] Subject [69] Author [4] Encoding [iso-8859-1,quoted-printable]
# DEBUG: Salut les gens, = https://serverfault.com/question
# -- Message [205100] Subject [69] Author [3] Encoding [UTF-8;,base64]
# DEBUG: This is a multi-part message in MIME format.
# -- Message [204971] Subject [70] Author [1] Encoding [utf-8,quoted-printable]
# DEBUG: This is an OpenPGP/MIME signed message (RFC 4880 a
# -- Message [204975] Subject [70] Author [2] Encoding ["UTF-8",8bit]
# DEBUG: Le mercredi 06 septembre 2017 à 23:12 +0200, Pier
# -- Message [204993] Subject [70] Author [1] Encoding [utf-8,quoted-printable]
# DEBUG: This is an OpenPGP/MIME signed message (RFC 4880 a
# -- Message [205003] Subject [70] Author [3] Encoding [utf-8,8bit]
# DEBUG: Le 07/09/2017 à 22:25, Pierre L. a écrit : A co
# -- Message [205004] Subject [70] Author [1] Encoding [utf-8,base64]
# DEBUG: This is an OpenPGP/MIME signed message (RFC 4880 a
# -- Message [205102] Subject [71] Author [1] Encoding [utf-8,quoted-printable]
# DEBUG: bonjour, j'envisage de monter une webradio et j'ai
# -- Message [205103] Subject [71] Author [2] Encoding [utf-8,8bit]
# DEBUG: Bonjour, nous on utilise mpd [ https://www.musicpd
# -- Message [205104] Subject [71] Author [3] Encoding [utf-8,8bit]
# DEBUG: Bonjour pour tout ce qui a trait à l'automation d
# -- Message [205106] Subject [71] Author [2] Encoding [utf-8,8bit]
# DEBUG: Bonjour, nous on utilise mpd [ https://www.musicpd
# -- Message [205115] Subject [71] Author [4] Encoding [utf-8,quoted-printable]
# DEBUG: =A0: Quelques autres informations : http://linuxma
# -- Message [205154] Subject [72] Author [1] Encoding [iso-8859-1,8bit]
# DEBUG: Bernard Schoenacker, le 2017-09-23 : Olivier Humbe
# -- Message [205014] Subject [73] Author [1] Encoding [utf-8,base64]
# DEBUG:
# -- Message [205015] Subject [73] Author [2] Encoding ["UTF-8",quoted-printable]
# DEBUG:
# -- Message [205016] Subject [73] Author [1] Encoding [utf-8,quoted-printable]
# DEBUG:
# -- Message [205017] Subject [73] Author [3] Encoding [utf-8,8bit]
# DEBUG: Salut, Il faut le paramétrer dans ton serveur web
# -- Message [205018] Subject [73] Author [2] Encoding ["UTF-8",quoted-printable]
# DEBUG:
# -- Message [205019] Subject [73] Author [3] Encoding [utf-8,8bit]
# DEBUG: Comme je viens de voir que c'était un Apache2 : h
# -- Message [205020] Subject [73] Author [1] Encoding [utf-8,quoted-printable]
# DEBUG:
# -- Message [205022] Subject [73] Author [2] Encoding ["UTF-8",quoted-printable]
# DEBUG:
# -- Message [205023] Subject [73] Author [4] Encoding [utf-8,8bit]
# DEBUG: 	Bonsoir, Le 12/09/2017 à 17:47, bernard.schoenac
# -- Message [205024] Subject [73] Author [4] Encoding [utf-8,8bit]
# DEBUG: Le 12/09/2017 à 21:22, Sébastien NOBILI a écrit
# -- Message [205052] Subject [73] Author [5] Encoding [utf-8,8bit]
# DEBUG: Il vaut mieux éviter de modifier ce fichier car i
# -- Message [205111] Subject [74] Author [1] Encoding [utf-8,quoted-printable]
# DEBUG: bonjour, j'ai relanc=C3=A9 opendmarc et voici le r
# -- Message [205112] Subject [74] Author [2] Encoding [iso-8859-1,quoted-printable]
# DEBUG: Bonsooooooooooir :-) M=EAme motif, m=EAme punition
# -- Message [205116] Subject [74] Author [1] Encoding [utf-8,quoted-printable]
# DEBUG:
# -- Message [205118] Subject [74] Author [3] Encoding [utf-8,8bit]
# DEBUG: Le 19/09/2017 à 03:48, bernard.schoenacker@free.f
# -- Message [205129] Subject [75] Author [1] Encoding ["UTF-8",quoted-printable]
# DEBUG:
# -- Message [205130] Subject [75] Author [2] Encoding [utf-8,8bit]
# DEBUG: J'utilise cela : BB=`tput bold`  # blod NN=`tput s
# -- Message [205131] Subject [75] Author [1] Encoding ["UTF-8",quoted-printable]
# DEBUG:
# -- Writing conversation on subject 7
# DEBUG: <s><utt uid="1"></utt><utt uid="2">Bonsoir, Pour vous embetez, la commande rm n'est pas si gourmande. Pour quoi ne=20 l'ex=E9cuter que s'il y a des fichiers ? rm -f /etc/apt/source.list.d/* Et c'est tout... S'il n'y a pas de fichier, il ne fait rien, et ne sort pas d'erreur grace = =E0=20 l'option -f.</utt></s>
# -- Writing conversation on subject 10
# DEBUG: <s><utt uid="1">online.net ? Le 15 septembre 2017 =C3=A0 10:12, David Martin <damart.vidin@gmail.com> a = =C3=A9crit : -vous</utt><utt uid="2"></utt><utt uid="2"></utt><utt uid="2"></utt><utt uid="2"></utt></s>
# -- Writing conversation on subject 14
# DEBUG: <s><utt uid="1">Le 09/20/17 à 17:25, Yves Rutschle a écrit : ET les saler avant, contrairement au steak.</utt><utt uid="2">Malheureusement, ce n'est pas moi qui produit le fichier... Je ne connais pas du tout le perl (et du coup pas tout compris...) mais j'ai réussi à bricoler un peu pour avoir un résultat qui me parait satisfaisant. Merci beaucoup.   Le script : #!/usr/bin/perl -w my $file1 =  $ARGV[0]; my $file2 =  $ARGV[1]; open(my $old, '<', $file1) or die "Can't open $file1: $!"; open(my $new, '<', $file2) or die "Can't open $file2: $!";   # Lire et indexer le premier fichier my %lines; foreach (<$old>) {     my ($f1, $f2, $f3, $email, $f4, $f5, $f6, $f7,$f8) = split /;/;     $lines{$email} = 1; } # Imprimer ce qui n'est pas dans le premier fichier foreach (<$new>) {     my ($f1, $f2, $f3, $email, $f4, $f5, $f6, $f7,$f8) = split /;/; print unless exists $lines{$email}; }</utt></s>
# -- Writing conversation on subject 16
# DEBUG: <s><utt uid="1">Le 24/09/2017 à 21:04, MERLIN Philippe a écrit : Personnellement, je prefere utiliser gparted grace a systemrescuecd plutot que gparted live. Ca permet de faire nettement plus d'opérations de maintenance et il y a une option qui permet de copier le contenu du CD dans la RAM puis booter sur l'image en RAM, ce qui libère le lecteur de CD et évite des plantages dus au temps que le CD met a redemarrer si il s'etait mis en pause.</utt><utt uid="2">Bonjour, tu chipotes un peu ;-) Attention avec l'option dont tu parles: Si on retire la cle USB une fois SystemRescueCD en RAM, il decale d'autant les noms des supports de stockage... Vaut mieux donc le faire tout de suite ou pas du tout. Avant de le savoir j'ai eu une mauvaise surprise en faisant une copie des donnees d'un personnel de l'universite avant changement de machine: l'operation durant plus longtemps que prevu, j'ai retire la cle en pleine copie pour aller dejeuner pendant ce temps la et patratra...</utt><utt uid="3">Le 25/09/2017 à 14:13, Stephane Ascoet a écrit : Cela m'étonne. Le noyau n'a aucune raison de renommer les périphériques de stockage lorsque l'un d'eux est ajouté ou retiré. Je ne l'ai d'ailleurs jamais constaté avec aucun système Linux.</utt></s>
# -- Writing conversation on subject 17
# DEBUG: <s><utt uid="1">Hello, Je ne suis pas sûr d'avoir compris comment était ton code à l'origine mais je pense qu'il n'était pas correct (ce qui ne l'a pas empêché de marcher pendant un certain temps semble-t-il). Avec les doubles quotes, tu demandes à bash de tester si un fichier qui s'appelle * (avec vraiment comme nom juste le caractère *) existe dans le répertoire /etc/apt/sources.list.d/. Et on imagine bien que ce n'est pas ce que tu veux demander à bash. Sans les doubles quotes, là le caractère * devient spécial et bash le développe en fonction de ce qu'il y a dans ton répertoire. Par exemple si dans /etc/apt/sources.list.d/, tu as titi.list et toto.list (et c'est tout) alors tout va se passer comme si tu avais écris : [ -e /etc/apt/sources.list.d/titi.list /etc/apt/sources.list.d/toto.list ] et là tu as fort logiquement une erreur vu que -e n'accepte _qu'un seul_ argument, pas plus. D'où le message d'erreur que tu obtiens. Si le répertoire ne contenait qu'un seul fichier, là ça marcherait. En fait, sans les "...", le code marche mais juste pour 0 ou 1 fichier dans le répertoire, pas plus. :) Perso, si je peux éviter les * dans un script, je le fais, surtout pour du rm. À ta place je ferais plutôt ceci :     find /etc/apt/sources.list.d/ -maxdepth 1 -mindepth 1 -type f -delete voire, tant qu'on y ait :     find /etc/apt/sources.list.d/ -maxdepth 1 -mindepth 1 -type f -name '*.list' -delete J'espère que c'est plus clair pour toi maintenant. À+</utt><utt uid="1">Je ne pense pas. On peut écrire : if [ -e "$fichier" ] then    ... Le « ; » est nécessaire si on met le then sur la même ligne : if [ -e "$fichier" ]; then    ... Perso, j'utilise toujours la première forme.</utt><utt uid="1">root@stretch-clean:~# ls /etc/apt/sources.list.d/ titi.list  toto.list root@stretch-clean:~# test /etc/apt/sources.list.d/* -bash: test: /etc/apt/sources.list.d/docker.list: unary operator expected</utt><utt uid="2">Re-bonjour, C'est tout à fait ça ;-) Il ne marchait pas avant mais je ne m'en rendais pas compte vu qu'il n'y a plus eu aucun fichier ajouté dans le répertoire... Le find est effectivement une solution plus adaptée... Merci à tous pour vos réponses. David. Le 08/09/2017 à 12:14, Francois Lafont a écrit :</utt><utt uid="1">... sauf si le répertoire /etc/apt/source.list.d/ contient un sous répertoire. Bon ok, je pinaille. :p</utt><utt uid="3">Bonsoir François, Vous pinaillez, oui et non, Si en-tête, le script a un `set -e` pour arrêter les frais en cas d'erreur, la présence d'un répertoire va stopper la procédure. J'aurais plutôt commis une purge dans le répertoire de sources de la manière suivante.  Si on force récursivement l'effacement du répertoire "/etc/apt/sources.list.d" tout entier, pas de risque de piège avec les astérisques puisqu'il n'y en a pas.  ;) Cette solution me semble sérieusement légitime, donc si quelqu'un y voit une énormité, qu'il n'hésite pas à le signaler, faut pas blaguer avec `rm`, même le vendredi. Votre solution à base de `find` était très bien, j'aurais raffiné encore un peu en ajoutant les fichiers .sources et en prenant en compte la majorité des types de fichiers, dès fois qu'un petit malin trouve le moyen de positionner un lien symbolique ou (soyons fous) une socket avec potentiellement de tout dedans : 	find /etc/apt/sources.list.d/			\ 		-maxdepth 1 -mindepth 1 		\ 		-not -type d 				\ 		-name '*.list' -or -name '*.sources'    \ 		-delete À plus,</utt></s>
# -- Writing conversation on subject 18
# DEBUG: <s><utt uid="1">This is a multi-part message in MIME format.</utt><utt uid="2">Tu peux essayer de jouer avec le cible LOG ( ou autre ) d'iptables qui te donnera l'uid et pid du processus faisant la requêtes.</utt></s>
# -- Writing conversation on subject 19
# DEBUG: <s><utt uid="1">Le 15/09/2017 à 10:12, David Martin a écrit : Je n'utilise pas de dédié actuellement. Cela ne répond pas à ta demande, mais, je partage tout de même quelques liens, pour quelques hébergements mutualisés, ou, VPS : https://www.visionduweb.eu/wiki/index.php?title=VPS_Gratuits_Payants</utt><utt uid="2">This is an OpenPGP/MIME signed message (RFC 4880 and 3156)</utt></s>
# -- Writing conversation on subject 20
# DEBUG: <s><utt uid="1">En fait, si j'ai bien compris ta demande, ça revient à exporter les signets de tes applications métier en html, ce que firefox sait faire. Cordialement</utt><utt uid="2">Bonjour, il y a aussi le Org-mode de Emacs qui est absolument magique, avec des possibilites quasiment illimitees, dommage que ce soit si peu connu: <http://data.passageenseine.org/2017/thierry-stoehr_orgmode-tout-faire-en-mode-texte.webm></utt></s>
# -- Writing conversation on subject 27
# DEBUG: <s><utt uid="1">Hello, [...] [...] Ça s'exécute forcément en root, je suppose ? Essaye un peu de coder le path de 'rm' en dur, sans reposer sur $PATH. Donc : [...] /bin/rm /etc/apt/sources.list.d/* Qu'est-ce que ça donne ? A+</utt><utt uid="2">salut, si tu mets ton * dans une chaine (""), c'est pour dire que tu cherches un fichier qui s'appelle litteralement *. ce que tu cherches a faire c'est   test /etc/apt/sources.list.d/* && 	  rm /etc/apt/sources.list.d/* autre approche (intéressante si beaucoup de fichiers)   find /etc/apt/sources.list.d -prune -maxdepth 1 -print0 | 	xargs -0 rm cordialement, marc</utt><utt uid="2">oops ... effectivement :) utilise find !</utt></s>
# -- Writing conversation on subject 28
# DEBUG: <s><utt uid="1">Lo, [...] Tu y arriverais avec ikiwiki. Ça prend du markdown en entrée, donc très proche du texte, et ça crache des fichiers html en sortie. Il y a juste que ton fichier devrait être conçu comme ceci : [production](http://lien-vers.application1) [preproduction](http://lien-vers.application2) Je ne sais pas si c'est le plus adapté, mais c'est tout fait et ça ferait (au moins) ce que tu veux... Hih,</utt><utt uid="2">degainer php pour ca me semble bien overkill ... pour transformer ca: http://example.fr haah mais trop bien http://example.fr haah mais trop bien http://example.fr haah mais trop bien en ca: <p> <a href="http://example.fr" target="_blank">haah mais trop bien</a> <a href="http://example.fr" target="_blank">haah mais trop bien</a> <a href="http://example.fr" target="_blank">haah mais trop bien</a> </p> voila qui me semble suffisant 	sed -r 's/^(\S+) +(.*)/[\2](\1){target="_blank"}/' | pandoc -thtml avec tous les avantages liés a pandoc : tu pourras avoir la sortie html, pdf, ajouter des templates ... au passage: j'aurais tendance a écrire tout en utilisant pandoc $ grep . links.* links.template:# list of my links links.template:$for(links)$ [$links.desc$]($links.url$) $endfor$ links.yml:--- links.yml:links: links.yml:    - {url: "http://les exemples (pas cools)", desc: "voici une URL flinguée"} links.yml:    - {url: "http://les.exemples"            , desc:  "une 2eme pour la route"} links.yml:oops: links.yml:    - ["hello","world"] links.yml:--- $ pandoc --template links.template links.yml|pandoc  <h1 id="list-of-my-links">list of my links</h1>  <p><a href="http://les%20exemples%20(pas%20cools)">voici une URL  flinguée</a> <a href="http://les.exemples">une 2eme pour la  route</a></p> si tu ajoute un -s au dernier pandoc, il te fait une page complete. cordialement, marc</utt><utt uid="2">c'était pas toi mais david qui parlait de php et toi de python. les deux me paraissent à éviter en toute circonstance :) bon we marc </utt><utt uid="2">pardon ... j'aurais du me garder de cette phrase pleine de subjectivité. maintenant si tu veux une réponse plus constructive: * j'ai tendance à ne dégainer les interpreteurs que quand je n'ai pas a de   commande a ma disposition qui fasse le taff (c'était le cas en   l'occurence) * si je dois dégainer un langage dynamique, j'ai perl comme fleche a mon   arc et du coup les autres langages dynamiques me semblent bien   tristounes ... laissons a python que ca s'ameliore doucement (PEP 448   et 498 vont vraiment dans le bon sens ... mais c'est pas encore dispo   dans debian) cordialement, marc</utt><utt uid="2">non: on a juste plus d'heures de pratique que toi. ca viendra :)</utt></s>
# -- Writing conversation on subject 31
# DEBUG: <s><utt uid="1">Salut David, Je ne connais pas de projet libre qui fait ce que tu veux, mais un petit script python de quelques lignes devrait le faire facilement. Le tout couplé à une tâche cron pour mettre à jour ton fichier html et le tour est joué. HTH, Steve</utt><utt uid="1">Oups, ma langue a fourché, je voulais dire python  ;)</utt><utt uid="1">D'accord avec le premier, mais pourquoi diable le second ? :)</utt><utt uid="1">Et en plus on est 'dredi  ;)</utt><utt uid="1">Solution très élégante par ailleurs…</utt><utt uid="2">  Salut David,   Pour mettre en oeuvre la suggestion de Marc Chantreux : (en admettant que ton fichier se nomme « fichier.txt »), se placer dans son répertoire et : $ sed -r 's/^(\S+) +(.*)/[\2](\1){target="_blank"}/' fichier.txt | pandoc -s -thtml > fichier.html   Cette commande créera un nouveau « fichier.html » dans le même répertoire. (le '$' en début de ligne dénote l'invite de commande de l'utilisateur courrant dans l'émulateur de terminal)</utt></s>
# -- Writing conversation on subject 33
# DEBUG: <s><utt uid="1">Oups ! C'est le kernel qui est en v4 : "Powered by Linux kernel 4.1.3 LTS (Long-Term Support), GParted Live 0.23.0= -1 includes GParted 0.23.0, as well as all the updates released in the Debi= an Sid software repository as of August 6, 2015." Oups encore ! La commande est cryptsetup luksOpen ..... Pour le probl=C3=A8me de d=C3=A9chiffrement, je ne comprends pas comment pr= oc=C3=A9der exactement.=20 Man dit : luksOpen <device> <name> opens the LUKS partition <device> and sets up a mapping <name> after succes= sful verification of the supplied key material (either via key file by --ke= y-file, or via prompting). <name> semble pouvoir =C3=AAtre choisi, oui/non ? Merci</utt><utt uid="1">Merci Pascal, Avant de faire ce test : Le d=C3=A9chiffrement a bien fonctionn=C3=A9 pendant des mois.=20 Qu'est-ce qui a pu changer pour poser un probl=C3=A8me d'encodage de caract= =C3=A8res ? Piste ? il y a eu apparement un probl=C3=A8me de BIOS. Le syst=C3=A8me Windows  7 u= tilis=C3=A9 sur un disque suppl=C3=A9mentaire =C3=A9tait revenu avec heure = affich=C3=A9e "01/01/2008". =C3=87a arrive quand la batterie (de ce portabl= e) se d=C3=A9charge compl=C3=A8tement.=20 =C3=87a arrive depuis que j'ai remplac=C3=A9 un HD par un SSD.=20 Est-ce que le pb de BIOS et de batterie ont pu affecter le syst=C3=A8me Deb= ian ? De fa=C3=A7on g=C3=A9n=C3=A9rale, comment faire un diagnostic du syst=C3=A8= me ? (Encodage utilis=C3=A9, clavier, etc. ) Merci</utt><utt uid="1">Un gars =C3=A9voque le fait qu'un liveCD a endommag=C3=A9 ses keyslots : The problem seems to come from a liveusb that detected my partition as a sw= ap one someway and used the space of my keyslots to store there stuff. You can read the whole thread at http://www.saout.de/pipermail/dm-crypt/ = =E2=80=A6 02724.html Est-ce que mon LiveCD GParted aurait pu faire une si horrible  chose ? Merci</utt><utt uid="1">Bonjour Revoici le lien (copi=C3=A9 dans la barre d'URL, il appara=C3=AEt complet a= u moment o=C3=B9 je le colle) : http://www.saout.de/pipermail/dm-crypt/2012-September/002724.html Merci</utt><utt uid="1">Bonjour Concr=C3=A8tement, comment faut-il proc=C3=A9der ? Dans la commande suivante, que faut-il indiquer pour <name> ? cryptsetup luksOpen <device> <name> Je rappelle que l'on est certains de la passphrase.=20 Et que je ne comprends pas ce qui a =C3=A9t=C3=A9 chang=C3=A9 dans le syst= =C3=A8me pour que les caract=C3=A8res accentu=C3=A9s (qui apparaissent corr= ectement dans le terminal, juste avant que la passphrase soit exig=C3=A9e) = puissent ne plus =C3=AAtre reconnus par cryptsetup (ou les modules Debian q= ui invoquent cryptsetup?) Savez-vous exactementvous comment fonctionne cryptsetup et les modules Debi= an ? Merci</utt><utt uid="1">PS L'=C3=A9quipe Cryptsetup avait r=C3=A9pondu =C3=A0 ma question pr=C3=A9limi= naire du  01/09/2017 : "If it is problem with Debian distro, please fill bug against Debian crypts= etup component. Debian package contains a lot of cryptsetup scripts that are not maintained=  here. (If it is upstream cryptsetup problem, Debian maintainers will surely forwa= rd it here.)" https://gitlab.com/cryptsetup/cryptsetup/issues/342 D'o=C3=B9 la remarque dans mon email pr=C3=A9c=C3=A9dent :=20 comment demander =C3=A0 l'=C3=A9quipe Debian s'ils ont connaissance de ce p= robl=C3=A8me (et pour les alerter de pr=C3=A9venir les utilisateurs qui cho= isissent de chiffrer leur partition/device - sauf si =C3=A7a existe d=C3=A9= j=C3=A0 et que je n'ai pas vu l'alerte qui m'aurait =C3=A9t=C3=A9 donn=C3= =A9e !) GParted utilise une distribution Debian. J'ignore si cela peut avoir une incidence sur les essais men=C3=A9s avec di= ff=C3=A9rents encodages de la passphrase.</utt><utt uid="2">Bonjour, Pour la g=C3=A9n=C3=A9ration d'un bug : - https://www.debian.org/Bugs/ - https://www.debian.org/Bugs/Reporting Pour la saisie des accents, j'ai eu le probl=C3=A8me au d=C3=A9marrage du syst=C3=A8me. * Mon contexte : chiffrement et installation de Jessie depu ...
# -- Writing conversation on subject 43
# DEBUG: <s><utt uid="1">	Bonjour à tous, 	J'utilise sendmail depuis très très très longtemps sur des systèmes variés sans aucun problème. Depuis quelques jours, je me prends des erreurs du type : 	Deferred: 403 4.7.0 TLS handshake failed. sur un nombre de domaines croissant. Je viens de patcher sauvagement le sendmail de debian avec tls_failures.m4 issu de la prochain mouture de sendmail pour tenter de corriger ce problème pénible. 	J'obtiens cette erreur malgré des MX qui renvoient par exemple : openssl s_client -starttls smtp -connect mxav.alciom.com:25 CONNECTED(00000003) depth=2 C = GB, ST = Greater Manchester, L = Salford, O = COMODO CA Limited, CN = COMODO RSA Certification Authority verify return:1 depth=1 C = GB, ST = Greater Manchester, L = Salford, O = COMODO CA Limited, CN = COMODO RSA Domain Validation Secure Server CA verify return:1 depth=0 OU = Domain Control Validated, OU = Hosted by Dada S.p.A., OU = COMODO SSL Wildcard, CN = *.securemail.pro verify return:1</utt><utt uid="1">Rhohhh pétard, c'est encore bien pire que cela : https://lists.debian.org/debian-user/2017/09/msg00210.html J'aime bien Debian, mais les petits devs qui savent mieux que les autres ce qui est bon pour eux, ça me gave, mais ça me gave !... Autoritairement, openssl de Debian est patché pour n'accepter que TLS à partir de 1.2. On se contrefiche royalement de tout ce qui peut encore décider de n'utiliser que les versions inférieures et de tous les effets de bord.</utt><utt uid="2">J'ai eu un problème similaire avec postfix pour les mails en provenance de carrefour. Pour ne pas avoir ces ennuis j'ai figé la bibli libssl1.1 à la version 1.1.0f-3 alors que l'on en est à la version 1.1.0f-5 J'ai fait le bug https://bugs.debian.org/cgi-bin/bugreport.cgi?bug=873065 à ce sujet. Il y a aussi un patch proposé dans https://bugs.debian.org/cgi-bin/bugreport.cgi?bug=873334</utt><utt uid="3">Le 13/09/2017 à 15:00, BERTRAND Joël a écrit : Le paquet "apt-listchanges" permet voir les nouveautés lors des mises à jour. Lors de la mise à jour du paquet openssl j'ai eu le message : openssl (1.1.0f-5) unstable; urgency=medium   By default the minimum supported TLS version is 1.2. If you still need to talk to applications that only support TLS 1.0 you should configure the application to set the minimum supported version.  -- Kurt Roeckx <kurt@roeckx.be>  Thu, 24 Aug 2017 22:19:17 +0200 On peut retrouver cette info dans le fichier : /usr/share/doc/openssl/NEWS.Debian.gz</utt><utt uid="1">	Très certes. J'avais bien vu ça. Sauf que j'avais zappé l'effet de bord de serveur distants sur lesquels je n'ai pas la main. 	JKB</utt><utt uid="1">	Je viens de répondre sur ce bug. Et j'ai recompilé une version du paquet sans ce patch. C'est ce genre de petits trucs qui me fait de plus en plus migrer vers les BSD... 	Cordialement, 	JKB</utt><utt uid="4">C'est peut-être une question un peu naïve, mais est-ce raisonnable d'utiliser des versions instables de Debian dans ce qui semble être un environnement de prod ? Le 13/09/2017 à 15:00, BERTRAND Joël a écrit :</utt><utt uid="1">	Ce n'est pas unstable mais testing parce que stable est un peu ancienne pour les applications qui tournent sur cette machine. 	Habituellement, je fais très attention aux mises à jours. Je n'ai pas vu venir l'effet de bord (serveurs de mails distants qui refusaient la renégociation sur TLS). 	Nonobstant ceci, il est fort probable que ce paquet termine dans stable avec tous les problèmes qui s'ensuivront. Nous sommes exactement dans la situation d'il y a quelques années où un développeur Debian avait trouvé malin d'optimiser le code d'OpenSSL en introduisant une subtile erreur. Ici, on modifie le code de la bibliothèque parce que c'est certainement plus sécurisant en se foutant éperdument des conséquences et des problèmes d'interopérabilité. C'est un peu gênant. Et comme les logs se trouvent sur les serveurs distants sur lesquels on n'a pas la main, il peut se passer beaucoup de temps avant qu'on découvre le  ...
# -- Writing conversation on subject 46
# DEBUG: <s><utt uid="1">Tout d'abord si tu évitait d'envoyer les messages en HTML pleins de balises ça serait plus facile à lire en mode texte. Pour en arriver au sujet, tu n'aurais pas un sources.list avec des dépots de différentes versions ? stable + backport testing + unstable stable + deb-multimedia .... Ça expliquerait qu'il y ait à la fois une version de paquet installé et une autre version de paquet non installé.</utt><utt uid="2">Tout d'abord si tu évitait d'envoyer les messages en HTML pleins de balises ça serait plus facile à lire en mode texte. Pour en arriver au sujet, tu n'aurais pas un sources.list avec des dépots de différentes versions ? stable + backport testing + unstable stable + deb-multimedia .... Ça expliquerait qu'il y ait à la fois une version de paquet installé et une autre version de paquet non installé.</utt></s>
# -- Writing conversation on subject 51
# DEBUG: <s><utt uid="1">Bonsoir, andre_debian@numericable.fr writes: =C3=A9 C=E2=80=99est pas normal. As-tu les m=C3=AAmes lignes entre ta carte filaire et wifi=C2=A0? Peut-=C3= =AAtre auto lo aiderait=C2=A0: auto wlan0 iface wlan0 inet dhcp Cordialement,</utt><utt uid="2"> =C3=A9crit : =C3=A9 =80=A6 Je commencerais=20 =E2=80=99un Wicd ou =C2=A0=C2=BB. Il y a bien "auto wlan0" dans mon "/etc/network/interfaces". Au boot de Jessie, =C3=A7a n'accroche pas le n=C2=B0 IP, il faut donc taper =C3=A0 la mano en root "ifup wlan0", =C3=A7a met du temps... et enfin la connexion s'=C3=A9tablit. Cr=C3=A9er un daemon de connexion Wifi, pareil, m=C3=AAme probl=C3=A8me, revenir =C3=A0 la m=C3=A9thode mano console. J'ai adopt=C3=A9 "wicd", =C3=A7a marche bien avec connexion imm=C3=A9diate auto au boot. J'avais 2 ic=C3=B4nes wicd dans la barre des t=C3=A2ches en bas =C3=A0 droi= te, r=C3=A9solu, car il y avait un autre lanceur (que j'ai supprim=C3=A9) dans "/home/andre/.config/autostart/wicd.desktop". Donc, plus qu'une ic=C3=B4ne. Probl=C3=A8me r=C3=A9solu, sauf que je ne comprends pas pourquoi au boot le WiFi est r=C3=A9calcitrant en mode "/etc/network/interfaces" et pas avec wicd qui se connecte sans probl=C3=A8me et rapidement au WiFi. Bonne journ=C3=A9e, Andr=C3=A9</utt><utt uid="1">Pendant longtemps j=E2=80=99ai conserv=C3=A9 ma gestion du r=C3=A9seau avec=  le fichier interfaces tout en ayant network-manager. =C3=87a a toujours =C3=A9t=C3=A9 = cafouilleux, j=E2=80=99ai arr=C3=AAt=C3=A9 mercredi depuis que j=E2=80=99ai install=C3= =A9 Stretch et compte sur network-manager seul. andre_debian@numericable.fr writes: a =C3=A9crit : r=C3=A9 =80=A6 Je commencerais=20 =E2=80=99un Wicd ou =C2=A0=C2=BB. oite,</utt></s>
# -- Writing conversation on subject 53
# ...
# -- Writing conversation on subject 79
# DEBUG: <s><utt uid="1">Rapide, efficace... Bravo! (et merci infiniment)</utt><utt uid="2">Cette traduction a =E9t=E9 plac=E9e en relecture ? Moosh</utt></s>
# -- Writing conversation on subject 84
# DEBUG: <s><utt uid="1">This message is in MIME format.</utt><utt uid="2">This is a multi-part message in MIME format.</utt></s>
# -- Writing conversation on subject 109
# DEBUG: <s><utt uid="1"></utt><utt uid="2">Le 20 mai 2008 =E0 01:01, Jean-Jacques SOLARI a =E9crit : traduit =20 Excellent, je vais pointer ma page vers cette traduction. Merci Jean-Jacques.</utt></s>
# -- Writing conversation on subject 125
# DEBUG: <s><utt uid="1">Salut =E0 tous, Voici l'annonce de fin de traduction de la recommandation du W3C, 2004-03-16, =AB Le langage de balisage extensible vocal 2.0 =BB (Voice Extensible Markup Language). Adresse du document original : <http://www.w3.org/TR/2004/REC-voicexml20-20040316/> Adresse du document traduit : <http://www.yoyodesign.org/doc/w3c/voicexml20/> A bient=F4t, JJS.</utt><utt uid="2">Salut =E0 tous, Voici l'annonce de fin de traduction de la recommandation du W3C, 2004-03-16, =AB Le langage de balisage extensible vocal 2.0 =BB (Voice Extensible Markup Language). Adresse du document original : <http://www.w3.org/TR/2004/REC-voicexml20-20040316/> Adresse du document traduit : <http://www.yoyodesign.org/doc/w3c/voicexml20/> A bient=F4t, JJS.</utt></s>
# -- Writing conversation on subject 131
# DEBUG: <s><utt uid="1">Salut =C3=A0 tous, Voici l'annonce de la fin de la traduction de la recommandation du W3C du 14 octobre 2003 =C2=AB XForms 1.0 =C2=BB. Adresse du document original : <http://www.w3.org/TR/2003/REC-xforms-20031014/> Adresse du document traduit : <http://www.yoyodesign.org/doc/w3c/xforms1/> A bient=C3=B4t, JJS.</utt><utt uid="2"></utt></s>
# -- Writing conversation on subject 140
# DEBUG: <s><utt uid="1">Salut =C3=A0 tous, Voici l'annonce marquant le d=C3=A9but de la traduction de la recommandatio= n 'Extensible Markup Language (XML) 1.1' sise =C3=A0 : <http://www.w3.org/TR/2004/REC-xml11-20040204/> A bient=C3=B4t, JJS.</utt><utt uid="2">Bon ben celle-la je suis candidat pour la relire. Je me refere assez souvent a la version originale, donc ce sera plus facile. Par contre Jean-Jacques, il faut vraiment que tu arretes les amphetamines et que tu dormes un peu. Je sais que les nuits d'hiver sont longues, mais il faut te menager ;-).     Alexandre RODIERE .. fan numero 1 du traducteur francais numero 1 du W3C (mais qui arrivera a l'arreter ??)</utt></s>
# -- Writing conversation on subject 148
# DEBUG: <s><utt uid="1">Salut =C3=A0 tous, Voici l'annonce du commencement de la traduction de la recommandation 'Namespaces in XML 1.1', du 4 f=C3=A9vrier 2004, qui se trouve =C3=A0 : <http://www.w3.org/TR/2004/REC-xml-names11-20040204> A bient=C3=B4t, JJS.</utt><utt uid="2">Le 06 f=E9vr. 2004, =E0 07:18, J.J.SOLARI a =E9crit : cool.</utt></s>
# -- Writing conversation on subject 150
# DEBUG: <s><utt uid="1">This is an OpenPGP/MIME signed message (RFC 4880 and 3156)</utt><utt uid="2">On Tue, 15 Oct 2013 22:33:38 +0200, Grégory Roche  Dear Grégory, Thanks for the translation. It is now in the Translations DB: [[ Translations of the document: “Associating Style Sheets with XML documents  1.0 (Second Edition)” [...] Associer des feuilles de style à des documents XML 1.0 (Deuxième Édition)      French translation. Translator: Grégory Roche. [...] ]] cf.  <http://www.w3.org/2005/11/Translations/Query?lang=any&translator=any&date=any&docSelection=choose&rec=xml-stylesheet&note=none&tut=none&wai=none&i18n=none&qa=none&misc=none&sorting=byTechnology&output=FullHTML&submit=Submit> Best regards, Coralie</utt></s>
# -- Writing conversation on subject 154
# DEBUG: <s><utt uid="1">Salut =C3=A0 tous, Voici l'annonce du commencement de la traduction de la recommandation "Architecture of the World Wide Web, Volume 1", 2004-12-15. Adresse document original : <http://www.w3.org/TR/2004/REC-webarch-20041215/> A bient=C3=B4t, JJS.</utt><utt uid="1">=46r=C3=A9d=C3=A9ric Laurent 20/12/04 17:42 +0100: =2Ehtml =46r=C3=A9d=C3=A9ric, Mille excuses... N'ayant aucune r=C3=A9f=C3=A9rence dans mes archives de courier (archive locale de w3c-translators-fr), j'ai cr=C3=BB que le champs =C3=A9tait libre. =C3=80 toute chose malheur est bon : =C3=A7a m'a permis de mettre le doigt = sur une incoh=C3=A9rence de mon filtre (=C3=A0 spams). Je te laisse donc traduire en paix :-) JJS.</utt><utt uid="2">bonjour Jean Jacques il se trouve que j'ai bien commenc=E9 la traduction de ladite recommandation et qu'en plus je l'avais annonc=E9... (pour une fois que je t'avais pris de vitesse :) ) donc si tu veux bien... cordialement Fr=E9d=E9ric</utt><utt uid="2">je t'avais m=EAme cit=E9 :) http://lists.w3.org/Archives/Public/w3c-translators-fr/2004Nov/0000.html en pr=E9venant que je n'avais pas ta force de frappe ! :) fred</utt><utt uid="3">Salut =E0 tous, Voici l'annonce du commencement de la traduction de la recommandation "Architecture of the World Wide Web, Volume 1", 2004-12-15. Adresse document original : <http://www.w3.org/TR/2004/REC-webarch-20041215/> A bient=F4t, JJS.</utt></s>
# -- Writing conversation on subject 155
# DEBUG: <s><utt uid="1">Hi, going through translations I've found two different ways to translate the article and the word html; I'm wondering if there is a preference for either: le HTML 4.01 or l'HTML 4.01 (also for de l'HTML or du HTML; also same questions for XML and XHTML le XML or l'XML?? ) Thanks in advance to anyone who can clarify this. * * * Loose French translation below * * * Bonjour! Quand j'ai recherche dans quelques traductions en francais des documents du W3C, j'ai trouve que l'on ecrivait, parfois, "l'HTML" et parfois, "le HTML" et je voulais savoir:  quelle forme est preferee? En vous remerciant a l'avance de clarifier l'usage en ce cas-ci. C. E. Whitehead cewcathar@hotmail.com _________________________________________________________________ The average US Credit Score is 675. The cost to see yours: $0 by Experian. http://www.freecreditreport.com/pm/default.aspx?sc=660600&bcd=EMAILFOOTERAVERAGE</utt><utt uid="2">Le 10 avr. 2007 =E0 02:30, CE Whitehead a =E9crit : I guess it depends on the context, but there might be a rule for this. we say "l'UNESCO" but we say "le HCR" so I would favor "le HTML" I would say "du HTML" le XML and du XML</utt></s>
# -- Writing conversation on subject 156
# DEBUG: <s><utt uid="1">Bonjour, J'aimerais savoir s'il y a une pratique courante concernant les liens = dans les documents traduits. Par exemple, dans le document que je traduis actuellement de l'anglais = au fran=E7ais, il y a des liens qui dirigent l'utilisateur vers des = documents connexes.  Dans certains cas, il existe une version fran=E7aise de ces documents, dans d'autres cas non.  J'aurais tendance =E0 r=E9f=E9rer = l'utilisateur vers la version traduite lorsqu'elle est disponible mais je ne sais pas = si cela est permis. Meilleures salutations, Catherine</utt><utt uid="2">zara 15/02/05 18:17 -0500: raduite Catherine, Il est =C3=A0 d=C3=A9plorer que le W3C n'ait pas (encore) pris des mesures permettant une navigation automatique dans un espace de langue commun =C3=A0 plusieurs documents (hormi l'anglais, bien s=C3=BBr). Pour ma part, je double chaque lien menant vers un autre document du W3C par un lien (discret ?) vers la traduction de celui-ci, si elle existe, de cette fa=C3=A7on (pseudo HTML) avec une feuille de style : <lien>lien vers doc. du W3C</lien> <lien>vf</lien> Evidemment, cette solution pr=C3=A9sente des inconv=C3=A9nients sur lesquel= s je ne m'=C3=A9tendrai pas. Hormi le surcro=C3=AEt de travail au cours de la traduction proprement dite, l'inconv=C3=A9nient principal est celui selon lequel les liens en question sont inscrits en dur dans la traduction appelante, avec les cons=C3=A9quences suivantes :  - on ne dispose que d'une photographie de la situation des traductions =C3=A0 un moment donn=C3=A9 ; si un des documents cit=C3=A9s, p= as encore traduit =C3=A0 l'=C3=A9poque de la traduction du document citant, vi= ent =C3=A0 l'=C3=AAtre, on n'aurait pas d'autre choix, pour refl=C3=A9ter la no= uvelle situation, que de reprendre le document citant et y apporter les corrections n=C3=A9cessaires ;  - tout changement dans l'h=C3=A9bergement d'une traduction est susceptible de briser cette fonctionnalit=C3=A9, m=C3=AAme en effectuant le= s redirections appropri=C3=A9es ;  - l'entretien de ces liens constitue un co=C3=BBt r=C3=A9dhibitoire en reg= ard du temps =C3=A0 y consacrer. +++++ La minute onirique +++++=20 Certains diront que je fais une fixation : il faudrait centraliser les informations de localisation des versions traduites. Id=C3=A9alement, cette t=C3=A2che devrait incomber au W3C ;-) <- clin d'oeil appuy=C3=A9 ici= =2E Mais les voies du W3C sont imp=C3=A9n=C3=A9trables, et j'ignore ses priorit= =C3=A9s et ses disponibilit=C3=A9s en ce qui concerne le mat=C3=A9riel (une base de donn=C3=A9es r=C3=A9pertoriant les adresses des traductions ne devrait pas consommer beaucoup de ressources), la capacit=C3=A9 d'acc=C3=A8s (?) et le temps humain (?). Consid=C3=A9rant cette facilit=C3=A9 comme un service rendu au lecteur et comme =C3=A7a me tient =C3=A0 c=C5=93ur (bis repetita), je pr=C3=A9vois d'i= nstaller, en d=C3=A9monstration, un tel dispositif, adoss=C3=A9 =C3=A0 une bdd, qui perm= ettra la redirection automatique d'un hyperlien (menant =C3=A0 un document du W3C) vers l'ancre =C3=A9quivalente d'une traduction et, =C3=A0 d=C3=A9faut, vers=  ce document du W3C. Ce dispositif se limiterait aux versions fran=C3=A7aises mais il pourrait facilement =C3=AAtre g=C3=A9n=C3=A9ralis=C3=A9 aux autres langues, simpleme= nt en alimentant la base de donn=C3=A9es. +++++ Fin de la minute +++++ En r=C3=A9ponse et pour finir, le traducteur est libre d'offrir =C3=A0 ses lecteurs tous les services suppl=C3=A9mentaires qu'il estime n=C3=A9cessair= es, =C3=A0 condition de respecter les clauses du copyright (cf. <http://www.w3.org/Consortium/Legal/IPR-FAQ.html#translate>), notamment, comme le dit I.Hermann sur la liste w3c-translators, garder absolument les liens vers les documents officiels en anglais. JJS.</utt></s>
# -- Writing conversation on subject 158
# DEBUG: <s><utt uid="1">Bonjour Est-il judicieux/n=E9cessaire/int=E9ressant/... de traduire, dans une sp=E9cification donn=E9e, les titres des chapitres d'autres = sp=E9cifications (externes donc) ? Deux cas se produisent : - le document externe r=E9f=E9renc=E9 poss=E8de une traduction = fran=E7aise, alors=20 le titre peut =EAtre l=E9gitimement mis en fran=E7ais (en s'assurant que = les deux libell=E9s soient coh=E9rents). Le lien est quant =E0 lui fait sur le = document en version anglaise (on peut par ailleurs rajouter un lien sur sa traduction). - le document externe r=E9f=E9renc=E9 ne poss=E8de pas de traduction = fran=E7aise : question : doit-on laisser le titre original ou en mettre un en fran=E7ais= qui ne refl=E8te pas la r=E9alit=E9, puisqu'il est fictif. Sachant que le document externe peut =EAtre une sp=E9cification mais = aussi=20 des notes, un mail,... bref toute sorte de document qu'en pensez vous ? cordialement Fr=E9d=E9ric</utt><utt uid="2">Bonjour, La question est intéressante :-) Je vois deux choses : 1. les titres doivent être exacts : donc j'aurais tendance à ne pas utiliser des titres en français fictifs mais à conserver l'anglais dans le cas où le document externe référencé ne possède pas de traduction en français. Dans le cas contraire, il est tentant de vouloir utiliser le titre tel qu'il a été traduit mais comme les liens sont faits vers des textes en anglais, ça peut surprendre le lecteur francophone de cliquer sur un lien en français et de se retrouver sur une page en anglais. 2. les titres doivent être compréhensibles par un lecteur francophone (c'est à priori c'est le but d'une traduction) : donc il faut tout de même inclure une traduction il me semble. Selon les cas, les occurences des titres dans le document à traduire, etc., le mieux est peut être de laisser le titre en anglais avec une traduction en français entre parenthèses (soit la "traduction d'usage" soit une nouvelle traduction). Comme ça la traduction reste à la fois exacte et compréhensible. Voilà pour mes 2 cents ;-) Cordialement, François Palaci</utt></s>
# -- Writing conversation on subject 159
# DEBUG: <s><utt uid="1"></utt><utt uid="2">On Thu, 03 Sep 2009 20:02:00 +0200, CE Whitehead <cewcathar@hotmail.com>  Yes, please, it is a very good idea to install a redirect to the new URL. Coralie</utt><utt uid="2">Le changement dans la DB sera effectué la semaine prochaine; la personne  en charge de la maintenance est en voyage d'affaire. Coralie On Fri, 04 Sep 2009 22:38:20 +0200, CE Whitehead <cewcathar@hotmail.com>  </utt></s>

# %%
hname="stats_author_"+group+".csv"
h=open(hname,'wb')
author_writer = csv.writer(h)
author_writer.writerow(['Conversation no.', 'No. of authors'])
